# %% [markdown]
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# import os
# print(os.listdir("..\Kuliah\Grapevine"))

# %%
import cv2
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
import seaborn as sns
import tensorflow as tf
import os
import random
from PIL import Image
from tensorflow.keras.preprocessing.image import load_img , img_to_array , ImageDataGenerator
from tensorflow.keras import Sequential, layers
from keras.utils import np_utils
import shutil

# %%
Ak_data = os.listdir('../Kuliah/Grapevine/Ak')
print(Ak_data[:10]) #the output we get are the .png files

AlaIdris_data = os.listdir('../Kuliah/Grapevine/Ala_Idris')
print('\n')
print(AlaIdris_data[:10])

Buzgulu_data = os.listdir('../Kuliah/Grapevine/Buzgulu')
print('\n')
print(Buzgulu_data[:10])
                          
Dimnit_data = os.listdir('../Kuliah/Grapevine/Dimnit')
print('\n')
print(Dimnit_data[:10])
                         
                         
Nazli_data = os.listdir('../Kuliah/Grapevine/Nazli')
print('\n')
print(Nazli_data[:10])
# Out:
# ['Ak (1).png', 'Ak (10).png', 'Ak (100).png', 'Ak (11).png', 'Ak (12).png', 'Ak (13).png', 'Ak (14).png', 'Ak (15).png', 'Ak (16).png', 'Ak (17).png']
#
#
# ['Ala_Idris (1).png', 'Ala_Idris (10).png', 'Ala_Idris (100).png', 'Ala_Idris (11).png', 'Ala_Idris (12).png', 'Ala_Idris (13).png', 'Ala_Idris (14).png', 'Ala_Idris (15).png', 'Ala_Idris (16).png', 'Ala_Idris (17).png']
#
#
# ['Buzgulu (1).png', 'Buzgulu (10).png', 'Buzgulu (100).png', 'Buzgulu (11).png', 'Buzgulu (12).png', 'Buzgulu (13).png', 'Buzgulu (14).png', 'Buzgulu (15).png', 'Buzgulu (16).png', 'Buzgulu (17).png']
#
#
# ['Dimnit (1).png', 'Dimnit (10).png', 'Dimnit (100).png', 'Dimnit (11).png', 'Dimnit (12).png', 'Dimnit (13).png', 'Dimnit (14).png', 'Dimnit (15).png', 'Dimnit (16).png', 'Dimnit (17).png']
#
#
# ['Nazli (1).png', 'Nazli (10).png', 'Nazli (100).png', 'Nazli (11).png', 'Nazli (12).png', 'Nazli (13).png', 'Nazli (14).png', 'Nazli (15).png', 'Nazli (16).png', 'Nazli (17).png']

# %%
root_dir = os.path.join('..\Kuliah')
root_dir = os.path.join(root_dir , 'Grapevine')

# %%
classes_dirs = [os.path.join( root_dir, folder) for folder in os.listdir(root_dir) ]

# %%
classes_dirs
# Out:
# ['..\\Kuliah\\Grapevine\\Ak',
#  '..\\Kuliah\\Grapevine\\Ala_Idris',
#  '..\\Kuliah\\Grapevine\\Buzgulu',
#  '..\\Kuliah\\Grapevine\\Dimnit',
#  '..\\Kuliah\\Grapevine\\Nazli']

# %%
plt.figure(figsize = (5,5))
for i in range(2):
    plt.subplot(1, 2, i+1)
    img = cv2.imread('../Kuliah/Grapevine/Ak' + "/" + Ak_data[i])
    plt.imshow(img)
    plt.title('AK : 1')
    plt.tight_layout()
plt.show()
plt.figure(figsize = (5,5))
for i in range(2):
    plt.subplot(1, 2, i+1)
    img = cv2.imread('../Kuliah/Grapevine/Ala_Idris' + "/" + AlaIdris_data[i])
    plt.imshow(img)
    plt.title('ALAIDRIS : 2')
    plt.tight_layout()
plt.show()
plt.figure(figsize = (5,5))
for i in range(2):
    plt.subplot(1, 2, i+1)
    img = cv2.imread('../Kuliah/Grapevine/Buzgulu' + "/" + Buzgulu_data[i])
    plt.imshow(img)
    plt.title('BUZGULU : 3')
    plt.tight_layout()
plt.show()
plt.figure(figsize = (5,5))
for i in range(2):
    plt.subplot(1, 2, i+1)
    img = cv2.imread('../Kuliah/Grapevine/Dimnit' + "/" + Dimnit_data[i])
    plt.imshow(img)
    plt.title('DIMNIT : 4')
    plt.tight_layout()
plt.show()
plt.figure(figsize = (5,5))
for i in range(2):
    plt.subplot(1, 2, i+1)
    img = cv2.imread('../Kuliah/Grapevine/Nazli' + "/" + Nazli_data[i])
    plt.imshow(img)
    plt.title('NAZLI : 5')
    plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (12,12))
for i in range(4):
    plt.subplot(1, 4, i+1)
    img = cv2.imread('../Kuliah/Grapevine/Buzgulu' + "/" + Buzgulu_data[i])
    plt.imshow(img)
    plt.title('BUZGULU : 3')
    plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (12,12))
for i in range(4):
    plt.subplot(1, 4, i+1)
    img = cv2.imread('../Kuliah/Grapevine/Dimnit' + "/" + Dimnit_data[i])
    plt.imshow(img)
    plt.title('DIMNIT : 4')
    plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (12,12))
for i in range(4):
    plt.subplot(1, 4, i+1)
    img = cv2.imread('../Kuliah/Grapevine/Nazli' + "/" + Nazli_data[i])
    plt.imshow(img)
    plt.title('NAZLI : ')
    plt.tight_layout()
plt.show()

# %%
base_dir = os.path.join('data')

train_dir = os.path.join(base_dir , 'train')
validation_dir = os.path.join(base_dir , 'validation')

Ak_train_dir = os.path.join(train_dir ,'AK' )
Ala_Idris_train_dir  = os.path.join(train_dir , 'Ala_Idris')
Buzgulu_train_dir = os.path.join(train_dir , 'Buzgulu')
Dimnit_train_dir = os.path.join(train_dir ,'Dimnit' )
Nazli_train_dir = os.path.join(train_dir , 'Nazli')

# %%
Ak_validation_dir = os.path.join(validation_dir ,'AK' )
Ala_Idris_validation_dir  = os.path.join(validation_dir , 'Ala_Idris')
Buzgulu_validation_dir = os.path.join(validation_dir , 'Buzgulu')
Dimnit_validation_dir = os.path.join(validation_dir ,'Dimnit' )
Nazli_validation_dir = os.path.join(validation_dir , 'Nazli')

# %%
def create_directory(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
create_directory(Ak_train_dir)
create_directory(Ala_Idris_train_dir)
create_directory(Buzgulu_train_dir)
create_directory(Dimnit_train_dir )
create_directory(Nazli_train_dir)

# %%
create_directory(Ak_validation_dir)
create_directory(Ala_Idris_validation_dir)
create_directory(Buzgulu_validation_dir)
create_directory(Dimnit_validation_dir )
create_directory(Nazli_validation_dir)

# %%
validation_classes =[Ak_validation_dir,
Ala_Idris_validation_dir ,
Buzgulu_validation_dir ,
Dimnit_validation_dir ,
Nazli_validation_dir]

# %%
train_classes = [Ak_train_dir,
Ala_Idris_train_dir ,
Buzgulu_train_dir ,
Dimnit_train_dir ,
Nazli_train_dir]

# %%
samples = []
for class_ in classes_dirs:
    paths = os.listdir(class_)
    paths = random.sample(paths , 4)
    samples.append([os.path.join( class_, path) for path in paths])

# %%
#lets flatten samples array
samples = [ele for arr_ in samples for ele in arr_  ]

# %%
samples
# Out:
# ['..\\Kuliah\\Grapevine\\Ak\\Ak (28).png',
#  '..\\Kuliah\\Grapevine\\Ak\\Ak (33).png',
#  '..\\Kuliah\\Grapevine\\Ak\\Ak (40).png',
#  '..\\Kuliah\\Grapevine\\Ak\\Ak (23).png',
#  '..\\Kuliah\\Grapevine\\Ala_Idris\\Ala_Idris (59).png',
#  '..\\Kuliah\\Grapevine\\Ala_Idris\\Ala_Idris (38).png',
#  '..\\Kuliah\\Grapevine\\Ala_Idris\\Ala_Idris (35).png',
#  '..\\Kuliah\\Grapevine\\Ala_Idris\\Ala_Idris (97).png',
#  '..\\Kuliah\\Grapevine\\Buzgulu\\Buzgulu (3).png',
#  '..\\Kuliah\\Grapevine\\Buzgulu\\Buzgulu (92).png',
#  '..\\Kuliah\\Grapevine\\Buzgulu\\Buzgulu (77).png',
#  '..\\Kuliah\\Grapevine\\Buzgulu\\Buzgulu (1).png',
#  '..\\Kuliah\\Grapevine\\Dimnit\\Dimnit (3).png',
#  '..\\Kuliah\\Grapevine\\Dimnit\\Dimnit (56).png',
#  '..\\Kuliah\\Grapevine\\Dimnit\\Dimnit (50).png',
#  '..\\Kuliah\\Grapevine\\Dimnit\\Dimnit (12).png',
#  '..\\Kuliah\\Grapevine\\Nazli\\Nazli (53).png',
#  '..\\Kuliah\\Grapevine\\Nazli\\Nazli (90).png',
#  '..\\Kuliah\\Grapevine\\Nazli\\Nazli (84).png',
# ...

# %%
fig = plt.gcf()
fig.set_size_inches(20 , 20)

for idx , ele in enumerate(samples):
    subplot = plt.subplot( 5 , 4,idx+1)
    img = mpimg.imread(ele)
    plt.imshow(img)

plt.show()

# %%
def copy_file(src_path , des_path , file_names):
    for file in file_names:
        shutil.copyfile(os.path.join(src_path,file) ,os.path.join( des_path , file))

# %%
def split_files(src_dir , train_dir , validation_dir , split_ration):
    if len(os.listdir(validation_dir)) == 0:
        split_size = int(len(os.listdir(src_dir)) * 0.8)
        path_selected = random.sample(os.listdir(src_dir) , split_size)
        copy_file(src_dir , train_dir , path_selected)
        rest_path_val = [path for path in os.listdir(src_dir) if path not in path_selected]
        copy_file(src_dir , validation_dir , rest_path_val)

# %%
split_ratio = 0.8
for idx , class_ in enumerate(classes_dirs):
    print('working with:' , class_)
    split_files(class_ ,train_classes[idx] , validation_classes[idx] , split_ratio )
# Out:
# working with: ..\Kuliah\Grapevine\Ak
# working with: ..\Kuliah\Grapevine\Ala_Idris
# working with: ..\Kuliah\Grapevine\Buzgulu
# working with: ..\Kuliah\Grapevine\Dimnit
# working with: ..\Kuliah\Grapevine\Nazli

# %%
train_gen = ImageDataGenerator(rescale = 1./255., 
                              rotation_range = 40 , 
                              shear_range = .2 , 
                              width_shift_range = .2,
                              height_shift_range = .2 , 
                              horizontal_flip=True,
                              vertical_flip= True ,
                               zoom_range=0.1,
                              fill_mode='nearest')

# %%
 from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_d_gen = train_gen.flow_from_directory(train_dir , class_mode = 'categorical' , target_size = (300, 300) , batch_size = 100)
# Out:
# Found 400 images belonging to 5 classes.

# %%
val_gen = ImageDataGenerator(rescale = 1./255.)

# %%
#compile the model
model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 #compile the model
# ----> 2 model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])
#
# NameError: name 'model' is not defined

# %%
val_d_gen = val_gen.flow_from_directory(validation_dir , class_mode = 'categorical' , target_size = (300, 300) , batch_size = 50)
# Out:
# Found 100 images belonging to 5 classes.

# %%
model = Sequential()
model.add(layers.Conv2D(filters=64, kernel_size=(2,2), kernel_initializer="he_uniform", input_shape=(300, 300,3), activation="relu"))
model.add(layers.MaxPool2D((3,3)))
model.add(layers.Conv2D(filters=64, kernel_size=(2,2), kernel_initializer="he_uniform", activation="relu"))
model.add(layers.MaxPool2D((3,3)))
model.add(layers.Conv2D(filters=64, kernel_size=(2,2), kernel_initializer="he_uniform", activation="relu"))
model.add(layers.MaxPool2D((3,3)))
model.add(layers.Conv2D(filters=64, kernel_size=(2,2), kernel_initializer="he_uniform", activation="relu"))
model.add(layers.MaxPool2D((3,3)))
model.add(layers.Flatten())
model.add(layers.Dense(units=256, kernel_initializer="he_uniform", activation="relu"))
model.add(layers.Dense(units=512, kernel_initializer="he_uniform", activation="relu"))
model.add(layers.Dense(units=64, kernel_initializer="he_uniform", activation="relu"))
model.add(layers.Dense(units=5, kernel_initializer="glorot_uniform", activation="softmax"))

model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_1256 (Conv2D)        (None, 299, 299, 64)      832
#
#  max_pooling2d_107 (MaxPooli  (None, 99, 99, 64)       0
#  ng2D)
#
#  conv2d_1257 (Conv2D)        (None, 98, 98, 64)        16448
#
#  max_pooling2d_108 (MaxPooli  (None, 32, 32, 64)       0
#  ng2D)
#
#  conv2d_1258 (Conv2D)        (None, 31, 31, 64)        16448
#
#  max_pooling2d_109 (MaxPooli  (None, 10, 10, 64)       0
#  ng2D)
#
#  conv2d_1259 (Conv2D)        (None, 9, 9, 64)          16448
#
#  max_pooling2d_110 (MaxPooli  (None, 3, 3, 64)         0
#  ng2D)
#
#  flatten_27 (Flatten)        (None, 576)               0
#
#  dense_76 (Dense)            (None, 256)               147712
#
#  dense_77 (Dense)            (None, 512)               131584
#
#  dense_78 (Dense)            (None, 64)                32832
#
# ...

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(
        optimizer=optimizer,
        loss="categorical_crossentropy",
        metrics=["accuracy"]
)

# %%
history = model.fit(train_d_gen, steps_per_epoch=3, epochs=5, validation_data=val_d_gen, validation_steps=2)
# Out:
# Epoch 1/5
# 3/3 [==============================] - 13s 4s/step - loss: 1.9955 - accuracy: 0.1767 - val_loss: 1.6685 - val_accuracy: 0.2300
# Epoch 2/5
# 3/3 [==============================] - 13s 4s/step - loss: 1.6437 - accuracy: 0.2033 - val_loss: 1.6277 - val_accuracy: 0.2300
# Epoch 3/5
# 3/3 [==============================] - 12s 4s/step - loss: 1.6327 - accuracy: 0.2100 - val_loss: 1.5999 - val_accuracy: 0.3100
# Epoch 4/5
# 3/3 [==============================] - 12s 4s/step - loss: 1.6265 - accuracy: 0.1867 - val_loss: 1.5938 - val_accuracy: 0.2000
# Epoch 5/5
# 3/3 [==============================] - 12s 4s/step - loss: 1.6111 - accuracy: 0.2200 - val_loss: 1.5826 - val_accuracy: 0.2600

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize = (10 , 5))

plt.plot(loss , 'b' , label = 'training loss')
plt.plot(val_loss , 'orange' , label = 'validation loss')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 loss = history.history['loss']
#       2 val_loss = history.history['val_loss']
#       4 plt.figure(figsize = (10 , 5))
#
# NameError: name 'history' is not defined

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(acc , 'b' , label = 'training acc')
plt.plot(val_acc , 'orange' , label = 'val acc')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 acc = history.history['accuracy']
#       2 val_acc = history.history['val_accuracy']
#       3 plt.figure(figsize = (10 , 5))
#
# NameError: name 'history' is not defined

# %%
model.evaluate(val_d_gen)
# Out:
# 2/2 [==============================] - 1s 441ms/step - loss: 1.5826 - accuracy: 0.2600
# [1.5826150178909302, 0.25999999046325684]

# %%
#I will use  InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

# %%
InceptionV3_model = tf.keras.applications.InceptionV3(weights='imagenet', include_top=False, input_shape=(300, 300, 3))

# %%
# The last 15 layers fine tune
for layer in InceptionV3_model.layers[:-15]:
    layer.trainable = False

x = InceptionV3_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dense(units=512, activation='relu')(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(units=512, activation='relu')(x)
x = layers.Dropout(0.2)(x)
output  = layers.Dense(units=5, activation='softmax')(x)
model = Model(InceptionV3_model.input, output)


model.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_14 (InputLayer)          [(None, 300, 300, 3  0           []
#                                 )]
#
#  conv2d_1260 (Conv2D)           (None, 149, 149, 32  864         ['input_14[0][0]']
#                                 )
#
#  batch_normalization_1200 (Batc  (None, 149, 149, 32  96         ['conv2d_1260[0][0]']
#  hNormalization)                )
#
#  activation_1192 (Activation)   (None, 149, 149, 32  0           ['batch_normalization_1200[0][0]'
#                                 )                                ]
#
#  conv2d_1261 (Conv2D)           (None, 147, 147, 32  9216        ['activation_1192[0][0]']
#                                 )
#
#  batch_normalization_1201 (Batc  (None, 147, 147, 32  96         ['conv2d_1261[0][0]']
#  hNormalization)                )
#
# ...

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(
        optimizer=optimizer,
        loss="categorical_crossentropy",
        metrics=["accuracy"])

# %%
history = model.fit(train_d_gen, steps_per_epoch=4, epochs=150, validation_data=val_d_gen, validation_steps=2)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 28s 7s/step - loss: 0.9204 - accuracy: 0.6325 - val_loss: 0.8953 - val_accuracy: 0.6900
# Epoch 2/150
# 4/4 [==============================] - 28s 7s/step - loss: 0.7902 - accuracy: 0.6925 - val_loss: 0.6318 - val_accuracy: 0.7100
# Epoch 3/150
# 4/4 [==============================] - 28s 7s/step - loss: 0.6460 - accuracy: 0.7550 - val_loss: 0.5729 - val_accuracy: 0.7300
# Epoch 4/150
# 4/4 [==============================] - 28s 7s/step - loss: 0.6230 - accuracy: 0.7575 - val_loss: 0.5670 - val_accuracy: 0.8100
# Epoch 5/150
# 4/4 [==============================] - 27s 7s/step - loss: 0.5074 - accuracy: 0.8025 - val_loss: 0.4831 - val_accuracy: 0.8400
# Epoch 6/150
# 4/4 [==============================] - 29s 8s/step - loss: 0.4394 - accuracy: 0.8125 - val_loss: 0.5042 - val_accuracy: 0.8500
# Epoch 7/150
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Validation accuracy')
plt.plot(epochs, val_acc, 'b', label='Training accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

plt.plot(epochs, loss, 'r', label='Validation loss')
plt.plot(epochs, val_loss, 'b', label='Training loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
val_acc = history.history['val_accuracy']
Max_Acc = np.max(val_acc)*100
print('Accuracy on the test set is=', round(Max_Acc,2),'%')

acc = history.history['accuracy']
Acc = np.max(acc)*100
print('Accuracy on the test set is=', round(Acc,2),'%')
# Out:
# Accuracy on the test set is= 95.0 %
# Accuracy on the test set is= 99.5 %

# %%
x = tf.keras.layers.Flatten()(last_output)
x = tf.keras.layers.Dense(100 , activation = 'relu')(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(5 , activation = 'softmax')(x)
pre_trained_model = tf.keras.models.Model(inputs = inception_v3.input , outputs = x)

# %%
pre_trained_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_7 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv2d_559 (Conv2D)            (None, 49, 49, 32)   864         ['input_7[0][0]']
#
#  batch_normalization_542 (Batch  (None, 49, 49, 32)  96          ['conv2d_559[0][0]']
#  Normalization)
#
#  activation_534 (Activation)    (None, 49, 49, 32)   0           ['batch_normalization_542[0][0]']
#
#  conv2d_560 (Conv2D)            (None, 47, 47, 32)   9216        ['activation_534[0][0]']
#
#  batch_normalization_543 (Batch  (None, 47, 47, 32)  96          ['conv2d_560[0][0]']
#  Normalization)
#
#  activation_535 (Activation)    (None, 47, 47, 32)   0           ['batch_normalization_543[0][0]']
#
# ...

# %%
pre_trained_model.compile(loss = tf.keras.losses.categorical_crossentropy , optimizer = tf.keras.optimizers.Adam() , metrics = ['accuracy'])

# %%
history_pre_trained = pre_trained_model.fit(train_d_gen , epochs = 50 , validation_data= val_d_gen)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 10s 266ms/step - loss: 1.6684 - accuracy: 0.3425 - val_loss: 1.1391 - val_accuracy: 0.5300
# Epoch 2/50
# 25/25 [==============================] - 6s 228ms/step - loss: 1.2320 - accuracy: 0.4925 - val_loss: 0.9485 - val_accuracy: 0.6600
# Epoch 3/50
# 25/25 [==============================] - 6s 239ms/step - loss: 1.1054 - accuracy: 0.5650 - val_loss: 0.9535 - val_accuracy: 0.5900
# Epoch 4/50
# 25/25 [==============================] - 6s 249ms/step - loss: 1.0196 - accuracy: 0.5975 - val_loss: 0.8179 - val_accuracy: 0.6400
# Epoch 5/50
# 25/25 [==============================] - 6s 245ms/step - loss: 1.0596 - accuracy: 0.6075 - val_loss: 0.7757 - val_accuracy: 0.6800
# Epoch 6/50
# 25/25 [==============================] - 6s 235ms/step - loss: 0.9720 - accuracy: 0.6275 - val_loss: 0.8228 - val_accuracy: 0.6600
# Epoch 7/50
# ...

# %%
loss = history_pre_trained.history['loss']
val_loss = history_pre_trained.history['val_loss']
acc = history_pre_trained.history['accuracy']
val_acc = history_pre_trained.history['val_accuracy']

plt.figure(figsize = (10 , 5))
plt.plot(loss , 'b' , label = 'training loss')
plt.plot(val_loss , 'orange' , label = 'validation loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10 , 5))
plt.plot(acc , 'b' , label = 'training accuracy')
plt.plot(val_acc , 'orange' , label = 'validation accuracy')
plt.legend()
plt.show()

# %%
pre_trained_model.evaluate(val_d_gen)
# Out:
# 50/50 [==============================] - 2s 45ms/step - loss: 0.5917 - accuracy: 0.7700
# [0.5916585922241211, 0.7699999809265137]
